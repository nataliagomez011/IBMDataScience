# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ## Herramientas para la Ciencia de Datos - Natalia Gómez Rojas

# %% [markdown]
# ##### Objetivo Principal del Proyecto: Mejorar las habilidades en Jupyter Notebook adquiridas en el curso. Abordaremos varios ejercicios para reforzar nuestro conocimiento y habilidades, que incluyen la documentación en Markdown, la programación en Python y la integración con GitHub. También practicaremos tareas fundamentales en la ciencia de datos.

# %% [markdown]
# ### Lenguajes de Ciencia de Datos
# - Python
# - R
# - Julia

# %% [markdown]
# ### Bibliotecas de Ciencia de Datos
# - NumPy
# - Pandas
# - Matplotlib

# %% [markdown]
# ### Herramientas de Ciencia de Datos
#
# | Herramienta       | Descripción           |
# | ----------------- | --------------------- |
# | Jupyter Notebook  | Entorno de desarrollo |
# | Scikit-learn      | Aprendizaje automático |
# | TensorFlow        | Biblioteca de ML      |

# %% [markdown]
# ### Ejemplos expresiones aritméticas
#
# #### A continuación, se explicarán las diferentes expresiones aritméticas que se pueden realizar en archivos de Python.
#
# ##### Suma

# %%
suma = 1+3
print(suma)

# %% [markdown]
# ##### Resta

# %%
resta = 10-2
print(resta)

# %% [markdown]
# ##### Multiplicacion

# %%
multiplicacion = 4*6
print(multiplicacion)

# %% [markdown]
# ##### Division

# %%
division = 25/5
print(division)
# Out:
# 5.0

# %% [markdown]
# ### Conversión de minutos a horas

# %%
minutos = 120
horas = minutos / 60

horas

# %% [markdown]
# ### Objetivos
#
# - Aplicar los conceptos aprendidos en el curso.
# - Mejorar las habilidades en programación.
# - Ampliar el conocimiento en ciencia de datos.
# - Fortalecer la capacidad de resolución de problemas.

# %% [markdown]
# ### Nombre del autor
#
# #### Natalia Gómez Rojas
